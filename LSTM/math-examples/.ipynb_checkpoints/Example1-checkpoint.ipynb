# %% [markdown]
# ### LSTM training and testing
#
# ### Input: x = 0:0.02:3
# ### Output: y = sin(2.pi.x) + N, where N = Uniform Random Number between 0 and 1 (data-train, \*2, \*3.csv)
# ##           or
# ### Output: y = tanh(3(x-1.5)) + N, where N = Uniform Random Number between 0 and 1 (data-train4.csv)

# %%
# LSTM for international airline passengers problem with regression framing
import numpy
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return numpy.array(dataX), numpy.array(dataY)

# fix random seed for reproducibility
numpy.random.seed(7)

# load the dataset
# dataframe = read_csv('data-train2.csv', usecols=[1], engine='python', skipfooter=3) # no noise
dataframe = read_csv('data-train2.csv', usecols=[1], engine='python', skipfooter=3) # 1.0 uniform noise
# dataframe = read_csv('data-train2.csv', usecols=[1], engine='python', skipfooter=3) # 0.5 uniform noise
#dataframe = read_csv('data-train4.csv', usecols=[1], engine='python', skipfooter=3) # 1.0 uniform noise

dataset = dataframe.values

dataset = dataset.astype('float32')

# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# reshape into X=t and Y=t+1
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# reshape input to be [samples, time steps, features]
trainX = numpy.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = numpy.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %% [markdown]
# ## Train LSTM and Predict

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(1, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=1)

# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# Out:
# Epoch 1/100
# 97/97 [==============================] - 4s 36ms/step - loss: 0.2280
# Epoch 2/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.1242
# Epoch 3/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0663
# Epoch 4/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0487
# Epoch 5/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0441
# Epoch 6/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0418
# Epoch 7/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0397
# Epoch 8/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0376
# Epoch 9/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0353
# Epoch 10/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0335
# Epoch 11/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0318
# Epoch 12/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0305
# Epoch 13/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0289
# Epoch 14/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0277
# Epoch 15/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0268
# Epoch 16/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0259
# Epoch 17/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0257
# Epoch 18/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0247
# Epoch 19/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0245
# Epoch 20/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0239
# Epoch 21/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0238
# Epoch 22/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0237
# Epoch 23/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0233
# Epoch 24/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 25/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0229
# Epoch 26/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0230
# Epoch 27/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0230
# Epoch 28/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0228
# Epoch 29/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0232
# Epoch 30/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0228
# Epoch 31/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0232
# Epoch 32/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0232
# Epoch 33/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0232
# Epoch 34/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0233
# Epoch 35/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0230
# Epoch 36/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0228
# Epoch 37/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0229
# Epoch 38/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0227
# Epoch 39/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0229
# Epoch 40/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0228
# Epoch 41/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0227
# Epoch 42/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0227
# Epoch 43/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0227
# Epoch 44/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0230
# Epoch 45/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0230
# Epoch 46/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0231
# Epoch 47/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0230
# Epoch 48/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0231
# Epoch 49/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0232
# Epoch 50/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0227
# Epoch 51/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0228
# Epoch 52/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0229
# Epoch 53/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0227
# Epoch 54/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0226
# Epoch 55/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0227
# Epoch 56/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0228
# Epoch 57/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0228
# Epoch 58/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0231
# Epoch 59/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0227
# Epoch 60/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0227
# Epoch 61/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0228
# Epoch 62/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0230
# Epoch 63/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0228
# Epoch 64/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0228
# Epoch 65/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0229
# Epoch 66/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0230
# Epoch 67/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0229
# Epoch 68/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0226
# Epoch 69/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0226
# Epoch 70/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0228
# Epoch 71/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0230
# Epoch 72/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0228
# Epoch 73/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0230
# Epoch 74/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0229
# Epoch 75/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0228
# Epoch 76/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0226
# Epoch 77/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0227
# Epoch 78/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0227
# Epoch 79/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0229
# Epoch 80/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0228
# Epoch 81/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0228
# Epoch 82/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0227
# Epoch 83/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0227
# Epoch 84/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0228
# Epoch 85/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0230
# Epoch 86/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0228
# Epoch 87/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0228
# Epoch 88/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0224
# Epoch 89/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0228
# Epoch 90/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0227
# Epoch 91/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0226
# Epoch 92/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0229
# Epoch 93/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0228
# Epoch 94/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0228
# Epoch 95/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0229
# Epoch 96/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0225
# Epoch 97/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0229
# Epoch 98/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0228
# Epoch 99/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0230
# Epoch 100/100
# 97/97 [==============================] - 0s 1ms/step - loss: 0.0228

# %% [markdown]
# ## Create Plots

# %%
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))

# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# Out:
# Train Score: 0.42 RMSE
# Test Score: 0.37 RMSE

# %%
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.legend(('total data','training data', 'predicted data'))

plt.show()

# %% [markdown]
# ## First Test Data
#
# ### Input: x = 0:0.02:3
# ### Output: y = sin(pi.x)

# %%
# load the dataset
dataframe2 = read_csv('data-test.csv', usecols=[1], engine='python', skipfooter=3)
dataset2 = dataframe2.values
dataset2 = dataset2.astype('float32')

# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset2 = scaler.fit_transform(dataset2)

test2 = dataset2

# look_back = 1
testX2, testY2 = create_dataset(test2, look_back)
testX2 = numpy.reshape(testX2, (testX2.shape[0], 1, testX2.shape[1]))

testPredict2 = model.predict(testX2)

testPredict2 = scaler.inverse_transform(testPredict2)
testY2 = scaler.inverse_transform([testY2])

testScore2 = math.sqrt(mean_squared_error(testY2[0], testPredict2[:,0]))
print('Test Score 2: %.2f RMSE' % (testScore2))

# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset2))
plt.plot(testPredict2)
plt.legend(('test data', 'predicted data'))
plt.show()
# Out:
# Test Score 2: 0.15 RMSE

# %% [markdown]
# ## Second Test Data
#
# ### Input: x = 0:0.02:3
# ### Output: y = exp(-0.5.x)sin(4.pi.x)

# %%
# load the dataset
dataframe2 = read_csv('data-test2.csv', usecols=[1], engine='python', skipfooter=3)
dataset2 = dataframe2.values
dataset2 = dataset2.astype('float32')

# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset2 = scaler.fit_transform(dataset2)

test2 = dataset2

# look_back = 1
testX2, testY2 = create_dataset(test2, look_back)
testX2 = numpy.reshape(testX2, (testX2.shape[0], 1, testX2.shape[1]))

testPredict2 = model.predict(testX2)

testPredict2 = scaler.inverse_transform(testPredict2)
testY2 = scaler.inverse_transform([testY2])

testScore2 = math.sqrt(mean_squared_error(testY2[0], testPredict2[:,0]))
print('Test Score 2: %.2f RMSE' % (testScore2))

# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset2))
plt.plot(testPredict2)
plt.legend(('test data', 'predicted data'))
plt.show()
# Out:
# Test Score 2: 0.12 RMSE

# %% [markdown]
# ## Third Test Data
#
# ### Input: x = 0:0.02:3
# ### Output: y = sin(2.pi.x)sin(4.pi.x)

# %%
# load the dataset
dataframe2 = read_csv('data-test3.csv', usecols=[1], engine='python', skipfooter=3)
dataset2 = dataframe2.values
dataset2 = dataset2.astype('float32')

# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset2 = scaler.fit_transform(dataset2)

test2 = dataset2

# look_back = 1
testX2, testY2 = create_dataset(test2, look_back)
testX2 = numpy.reshape(testX2, (testX2.shape[0], 1, testX2.shape[1]))

testPredict2 = model.predict(testX2)

testPredict2 = scaler.inverse_transform(testPredict2)
testY2 = scaler.inverse_transform([testY2])

testScore2 = math.sqrt(mean_squared_error(testY2[0], testPredict2[:,0]))
print('Test Score 2: %.2f RMSE' % (testScore2))

# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset2))
plt.plot(testPredict2)
plt.legend(('test data', 'predicted data'))
plt.show()
# Out:
# Test Score 2: 0.16 RMSE

# %% [markdown]
# ## FourthTest Data
#
# ### Input: x = 0:0.02:3
# ### Output: y = sin(2.pi.x)sin(4.pi.x)

# %%
# load the dataset
dataframe2 = read_csv('data-test4.csv', usecols=[1], engine='python', skipfooter=3)
dataset2 = dataframe2.values
dataset2 = dataset2.astype('float32')

# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset2 = scaler.fit_transform(dataset2)

test2 = dataset2

# look_back = 1
testX2, testY2 = create_dataset(test2, look_back)
testX2 = numpy.reshape(testX2, (testX2.shape[0], 1, testX2.shape[1]))

testPredict2 = model.predict(testX2)

testPredict2 = scaler.inverse_transform(testPredict2)
testY2 = scaler.inverse_transform([testY2])

testScore2 = math.sqrt(mean_squared_error(testY2[0], testPredict2[:,0]))
print('Test Score 2: %.2f RMSE' % (testScore2))

# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset2))
plt.plot(testPredict2)
plt.legend(('test data', 'predicted data'))
plt.show()
# Out:
# Test Score 2: 0.17 RMSE

# %% [markdown]
# ## Fifth Test Data
#
# ### Input x = 0:0.02:3
# ### Output y = tanh(3\*(x-1.5))+0.5\*rand()

# %%
# load the dataset
dataframe2 = read_csv('data-test5.csv', usecols=[1], engine='python', skipfooter=3)
dataset2 = dataframe2.values
dataset2 = dataset2.astype('float32')

# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset2 = scaler.fit_transform(dataset2)

test2 = dataset2

# look_back = 1
testX2, testY2 = create_dataset(test2, look_back)
testX2 = numpy.reshape(testX2, (testX2.shape[0], 1, testX2.shape[1]))

testPredict2 = model.predict(testX2)

testPredict2 = scaler.inverse_transform(testPredict2)
testY2 = scaler.inverse_transform([testY2])

testScore2 = math.sqrt(mean_squared_error(testY2[0], testPredict2[:,0]))
print('Test Score 2: %.2f RMSE' % (testScore2))

# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset2))
plt.plot(testPredict2)
plt.legend(('test data', 'predicted data'))
plt.show()
# Out:
# Test Score 2: 0.25 RMSE
